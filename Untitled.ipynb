# %%
import pandas as pd
import numpy as np

# 1️⃣ Data Obat (50 Nama Obat dengan Kategori Tetap)
medicine_data = [
    ("Paracetamol", "Painkiller"), ("Ibuprofen", "Painkiller"), ("Aspirin", "Painkiller"),
    ("Naproxen", "Painkiller"), ("Ketoprofen", "Painkiller"),
    ("Amoxicillin", "Antibiotic"), ("Azithromycin", "Antibiotic"), ("Ciprofloxacin", "Antibiotic"),
    ("Doxycycline", "Antibiotic"), ("Clindamycin", "Antibiotic"),
    ("Oseltamivir", "Antiviral"), ("Acyclovir", "Antiviral"), ("Remdesivir", "Antiviral"),
    ("Favipiravir", "Antiviral"), ("Zanamivir", "Antiviral"),
    ("Metformin", "Diabetes"), ("Insulin", "Diabetes"), ("Glipizide", "Diabetes"),
    ("Sitagliptin", "Diabetes"), ("Pioglitazone", "Diabetes"),
    ("Atorvastatin", "Cardiovascular"), ("Simvastatin", "Cardiovascular"),
    ("Lisinopril", "Cardiovascular"), ("Amlodipine", "Cardiovascular"),
    ("Losartan", "Cardiovascular"),
    ("Furosemide", "Cardiovascular"), ("Hydrochlorothiazide", "Cardiovascular"),
    ("Spironolactone", "Cardiovascular"), ("Warfarin", "Cardiovascular"),
    ("Clopidogrel", "Cardiovascular"),
    ("Dexamethasone", "Immunosuppressant"), ("Prednisone", "Immunosuppressant"),
    ("Hydrocortisone", "Immunosuppressant"), ("Methotrexate", "Immunosuppressant"),
    ("Mycophenolate", "Immunosuppressant"),
    ("Levothyroxine", "Endocrine"), ("Propylthiouracil", "Endocrine"),
    ("Methimazole", "Endocrine"),
    ("Fluoxetine", "Psychiatric"), ("Sertraline", "Psychiatric"),
    ("Diazepam", "Psychiatric"), ("Lorazepam", "Psychiatric"),
    ("Alprazolam", "Psychiatric"), ("Haloperidol", "Psychiatric"),
    ("Risperidone", "Psychiatric"),
    ("Omeprazole", "Gastrointestinal"), ("Ranitidine", "Gastrointestinal"),
    ("Pantoprazole", "Gastrointestinal"), ("Esomeprazole", "Gastrointestinal"),
    ("Lansoprazole", "Gastrointestinal")
]

# 2️⃣ Data User (40 User dengan Kategori "Hospital" atau "Apotics")
np.random.seed(42)  # Agar hasil random tetap konsisten
user_names = [f"User_{i+1}" for i in range(100)]
user_categories = np.random.choice(["Hospital", "Apotics"], size=100)  # Random assign Hospital atau Apotics

df_users = pd.DataFrame({
    "User": user_names,
    "User Category": user_categories
})

# 3️⃣ Data Stok Obat per Pengguna (Setiap User Memiliki Semua Obat)
data = []

for user, user_category in zip(user_names, user_categories):
    for med_name, med_category in medicine_data:
        stock = np.random.randint(50, 500)  # Stok antara 50 - 500 unit
        restock_freq = np.random.randint(7, 30)  # Frekuensi restock 7-30 hari
        supplier_reliability = np.random.uniform(0.7, 1.0)  # Keandalan pemasok (0.7-1.0)
        data.append([
            user, user_category, med_name, med_category, stock, restock_freq, 
            supplier_reliability, np.nan, np.nan, np.nan  # `disease_score_1`, `disease_score_2`, `disease_score_3` = Null
        ])

# 4️⃣ DataFrame Final
df_final = pd.DataFrame(data, columns=[
    "User", "User Category", "Medicine Name", "Category", "Stock", 
    "Restock Frequency", "Supplier Reliability", "disease_score_1", "disease_score_2", "disease_score_3"
])

# 5️⃣ Simpan ke CSV
df_final.to_csv("medicine_stock_data.csv", index=False)

# Tampilkan beberapa data awal
print(df_final.head(10))  # Data Final Terintegrasi
# Out:
#      User User Category  Medicine Name    Category  Stock  Restock Frequency  \
# 0  User_1      Hospital    Paracetamol  Painkiller    240                 24
# 1  User_1      Hospital      Ibuprofen  Painkiller    211                 16
# 2  User_1      Hospital        Aspirin  Painkiller    319                 22
# 3  User_1      Hospital       Naproxen  Painkiller    264                 14
# 4  User_1      Hospital     Ketoprofen  Painkiller    286                 24
# 5  User_1      Hospital    Amoxicillin  Antibiotic    329                 19
# 6  User_1      Hospital   Azithromycin  Antibiotic     64                 19
# 7  User_1      Hospital  Ciprofloxacin  Antibiotic    376                 15
# 8  User_1      Hospital    Doxycycline  Antibiotic    185                 17
# 9  User_1      Hospital    Clindamycin  Antibiotic    441                  9
#
#    Supplier Reliability  disease_score_1  disease_score_2  disease_score_3
# 0              0.932540              NaN              NaN              NaN
# 1              0.968448              NaN              NaN              NaN
# 2              0.797962              NaN              NaN              NaN
# 3              0.953360              NaN              NaN              NaN
# 4              0.861908              NaN              NaN              NaN
# 5              0.742277              NaN              NaN              NaN
# 6              0.722365              NaN              NaN              NaN
# 7              0.931673              NaN              NaN              NaN
# 8              0.759653              NaN              NaN              NaN
# 9              0.937053              NaN              NaN              NaN

# %%
df_final
# Out:
#           User User Category Medicine Name          Category  Stock  \
# 0       User_1      Hospital   Paracetamol        Painkiller    240
# 1       User_1      Hospital     Ibuprofen        Painkiller    211
# 2       User_1      Hospital       Aspirin        Painkiller    319
# 3       User_1      Hospital      Naproxen        Painkiller    264
# 4       User_1      Hospital    Ketoprofen        Painkiller    286
# ...        ...           ...           ...               ...    ...
# 4995  User_100      Hospital    Omeprazole  Gastrointestinal     80
# 4996  User_100      Hospital    Ranitidine  Gastrointestinal    147
# 4997  User_100      Hospital  Pantoprazole  Gastrointestinal    108
# 4998  User_100      Hospital  Esomeprazole  Gastrointestinal    255
# 4999  User_100      Hospital  Lansoprazole  Gastrointestinal    434
#
#       Restock Frequency  Supplier Reliability  disease_score_1  \
# 0                    24              0.932540              NaN
# 1                    16              0.968448              NaN
# 2                    22              0.797962              NaN
# 3                    14              0.953360              NaN
# 4                    24              0.861908              NaN
# ...                 ...                   ...              ...
# 4995                 11              0.705729              NaN
# 4996                  8              0.890686              NaN
# 4997                  9              0.929837              NaN
# 4998                 20              0.947920              NaN
# 4999                 22              0.965969              NaN
#
#       disease_score_2  disease_score_3
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 4995              NaN              NaN
# 4996              NaN              NaN
# 4997              NaN              NaN
# 4998              NaN              NaN
# 4999              NaN              NaN
#
# [5000 rows x 10 columns]

# %%
import pandas as pd
import numpy as np

# 1️⃣ Daftar 20 Penyakit
diseases = [
    "Influenza", "Diabetes", "Hypertension", "Tuberculosis", "Dengue Fever",
    "Pneumonia", "Asthma", "Hepatitis B", "Hepatitis C", "Covid-19",
    "Heart Disease", "Stroke", "Malaria", "Measles", "Chickenpox",
    "Chronic Kidney Disease", "Liver Cirrhosis", "Bronchitis", "Depression", "Anxiety"
]

# 2️⃣ Zona (5 Area)
zones = ["Jakarta Selatan", "Jakarta Timur", "Depok", "Bekasi", "Tangerang"]

# 3️⃣ Generate Data
data = []
for zone in zones:
    for disease in diseases:
        incidence_rate = np.random.randint(10, 150)  # Angka kejadian per 1000 penduduk
        severity_index = round(np.random.uniform(0.2, 1.0), 2)  # Indeks keparahan 0.2 - 1.0
        data.append([disease, zone, incidence_rate, severity_index])

# 4️⃣ DataFrame
df_disease = pd.DataFrame(data, columns=[
    "Disease Name", "Zone", "Incidence Rate (per 1000 people)", "Severity Index (0-1)"
])

# 5️⃣ Simpan ke CSV
df_disease.to_csv("disease.csv", index=False)

# Tampilkan beberapa data awal
print(df_disease.head(10))  # Data Disease
# Out:
#    Disease Name             Zone  Incidence Rate (per 1000 people)  \
# 0     Influenza  Jakarta Selatan                                70
# 1      Diabetes  Jakarta Selatan                                99
# 2  Hypertension  Jakarta Selatan                                68
# 3  Tuberculosis  Jakarta Selatan                                25
# 4  Dengue Fever  Jakarta Selatan                               113
# 5     Pneumonia  Jakarta Selatan                                25
# 6        Asthma  Jakarta Selatan                               138
# 7   Hepatitis B  Jakarta Selatan                                21
# 8   Hepatitis C  Jakarta Selatan                                62
# 9      Covid-19  Jakarta Selatan                                58
#
#    Severity Index (0-1)
# 0                  0.47
# 1                  0.45
# 2                  0.67
# 3                  0.52
# 4                  0.61
# 5                  0.90
# 6                  0.29
# 7                  0.32
# 8                  0.68
# 9                  0.97

# %%
df_final.to_csv("medicine_stock_data.csv", index=False)
